# %%
# To Find Largest Of Three Numbers

Num1 = float(input("Enter 1st number:"))
Num2 = float(input("Enter 2nd number:"))
Num3 = float(input("Enter 3rd number:"))
if Num1 >= Num2 and Num1 >= Num3:
    Largest = Num1
elif Num2 >= Num1 and Num2 >= Num3:
    Largest = Num2
else: 
    Largest = Num3
print("The largest of the given three numbers is",Largest,".")
# Out:
# Enter 1st number: 0
# Enter 2nd number: 4
# Enter 3rd number: 2
# The largest of the given three numbers is 4.0 .
