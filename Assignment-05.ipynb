# %%
# PAN Number Validation Using Regular Expression

import re
PAN = input("Enter PAN Number:")
Pattern = r"^[A-Z]{5}[0-9]{4}[A-Z]$"
print(PAN)
if re.fullmatch(Pattern, PAN):
    print("Valid PAN Number")
else:
    print("Invalid PAN Number")
# Out:
# Enter PAN Number: ABCDE1234A
# ABCDE1234A
# Valid PAN Number
